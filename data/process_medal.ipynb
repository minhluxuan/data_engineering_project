# %%
import pandas as pd

# %%
medaltally = pd.read_csv('./raw/Olympic_Medal_Tally_History.csv')
medaltally
# Out:
#                    edition  edition_id  year        country country_noc  gold  \
# 0     1896 Summer Olympics           1  1896  United States         USA    11
# 1     1896 Summer Olympics           1  1896         Greece         GRE    10
# 2     1896 Summer Olympics           1  1896        Germany         GER     6
# 3     1896 Summer Olympics           1  1896         France         FRA     5
# 4     1896 Summer Olympics           1  1896  Great Britain         GBR     2
# ...                    ...         ...   ...            ...         ...   ...
# 1802     1906 Intercalated           4  1906         Canada         CAN     1
# 1803     1906 Intercalated           4  1906         Norway         NOR     1
# 1804     1906 Intercalated           4  1906    Netherlands         NED     0
# 1805     1906 Intercalated           4  1906      Australia         AUS     0
# 1806     1906 Intercalated           4  1906        Bohemia         BOH     0
#
#       silver  bronze  total
# ...

# %%
medaltally = medaltally.drop(columns=['edition', 'year', 'country', 'total'])
medaltally
# Out:
#       edition_id country_noc  gold  silver  bronze
# 0              1         USA    11       7       2
# 1              1         GRE    10      18      19
# 2              1         GER     6       5       2
# 3              1         FRA     5       4       2
# 4              1         GBR     2       3       2
# ...          ...         ...   ...     ...     ...
# 1802           4         CAN     1       1       0
# 1803           4         NOR     1       1       0
# 1804           4         NED     0       1       2
# 1805           4         AUS     0       0       3
# 1806           4         BOH     0       0       2
#
# [1807 rows x 5 columns]

# %%
medaltally.to_csv('./processed/olympic_medal_tally.csv', index=False)

# %%
games = pd.read_csv(
    'D:\Code\data_engineering_project\data\processed\Olympic_Games_Summary.csv')
games

# medaltally[medaltally["edition_id"] == 1452]
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_21664\2465160480.py:2: SyntaxWarning: invalid escape sequence '\C'
#   'D:\Code\data_engineering_project\data\processed\Olympic_Games_Summary.csv')
#                  edition  edition_id   edition_url  year  \
# 0   1896 Summer Olympics           1   /editions/1  1896
# 1   1900 Summer Olympics           2   /editions/2  1900
# 2   1904 Summer Olympics           3   /editions/3  1904
# 3   1908 Summer Olympics           5   /editions/5  1908
# 4   1912 Summer Olympics           6   /editions/6  1912
# ..                   ...         ...           ...   ...
# 59  2018 Winter Olympics          60  /editions/60  2018
# 60  2022 Winter Olympics          62  /editions/62  2022
# 61  2026 Winter Olympics          72  /editions/72  2026
# 62       1956 Equestrian          48  /editions/48  1956
# ...

# %%
medaltally_edition_ids = set(medaltally['edition_id'])
games_edition_ids = set(games['edition_id'])

# Find the edition_id values that are in games but not in medaltally
missing_edition_ids = games_edition_ids - medaltally_edition_ids
# missing_edition_ids
games[games['edition_id'].isin(missing_edition_ids)]
# Out:
#                  edition  edition_id    edition_url  year  \
# 5   1916 Summer Olympics          50   /editions/50  1916
# 11  1940 Summer Olympics          51   /editions/51  1940
# 12  1944 Summer Olympics          52   /editions/52  1944
# 32  2024 Summer Olympics          63   /editions/63  2024
# 33  2028 Summer Olympics          64   /editions/64  2028
# 34  2032 Summer Olympics         372  /editions/372  2032
# 39  1940 Winter Olympics          55   /editions/55  1940
# 40  1944 Winter Olympics          56   /editions/56  1944
# 61  2026 Winter Olympics          72   /editions/72  2026
#
#                         city  \
# 5                     Berlin
# 11                  Helsinki
# 12                    London
# 32                     Paris
# 33               Los Angeles
# 34                  Brisbane
# 39    Garmisch-Partenkirchen
# 40         Cortina d'Ampezzo
# 61  Milano-Cortina d'Ampezzo
#
# ...
